# %% [markdown]
# <a href="https://colab.research.google.com/github/E-Troll/teste/blob/main/Grafico_Mtcars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dados <- mtcars

# %%
plot(dados$mpg, dados$wt, pch=19, col="blue")
# Out:
# plot without title

# %%
hist(dados$disp)
# Out:
# Plot with title “Histogram of dados$disp”
